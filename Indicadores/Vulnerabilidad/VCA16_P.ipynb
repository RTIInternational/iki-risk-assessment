# %% [markdown]
# ### This notebook computes the "VCA16_P. Relative frequency of recovery from failure for the demographic sector" indicator for the 27 basins of IKI Project
#
# **Spanish:** Frecuencia relativa de recuperacion a la falla para el sector poblacional
#
# **Created:** 1/22/2026 by Sophia Bakar (sbakar@rti.org)
#
# **Project #:** 0219481
#
# **Last modified:**
#
# **Status:** in progress
#
# **QA Status:** reviewed by
#
# **Inputs:**
#
# **Outputs:**
#
# **Assumptions:**
#
# **Future work:**
#
# **Notes/Summary:** The frequency with which a period without deficiencies occurs after a period that experienced deficiencies, expressed as a percentage of the total number of periods with deficiencies.
