# %% [markdown]
# ### This notebook computes the "VCA17_E. Percentage of net imported water volume relative to total water demand for the energy sector" indicator for the 27 basins of IKI Project
#
# **Spanish:** Porcentaje del volumen de agua importado neto con respecto a la demanda total de agua para el sector energetico.
#
# **Created:** 1/22/2026 by Sophia Bakar (sbakar@rti.org)
#
# **Project #:** 0219481
#
# **Last modified:**
#
# **Status:** in progress
#
# **QA Status:** reviewed by
#
# **Inputs:**
#
# **Outputs:**
#
# **Assumptions:**
#
# **Future work:**
#
# **Notes/Summary:**
