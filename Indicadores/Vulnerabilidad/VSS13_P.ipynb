# %% [markdown]
# ### This notebook computes the "VSS13_P. Index of Hydrological Stress for the Demographic Sector" indicator for the 27 basins of IKI Project
#
# **Spanish:** Indice de Estres Hidrico para el sector poblacional
#
# **Created:** 1/22/2026 by Sophia Bakar (sbakar@rti.org)
#
# **Project #:** 0219481
#
# **Last modified:**
#
# **Status:** in progress
#
# **QA Status:** reviewed by
#
# **Inputs:**
#
# **Outputs:**
#
# **Assumptions:**
#
# **Future work:**
#
# **Notes:**
