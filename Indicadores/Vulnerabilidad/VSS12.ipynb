# %% [markdown]
# ### This notebook computes the "VSS12. Average deficit of supply for the municipal sector" indicator for the 27 basins of IKI Project
#
# **Spanish:** Déficit Promedio: Magnitud promedio del déficit de suministro en el sector poblacional
#
# **Created:** 1/22/2026 by Sophia Bakar (sbakar@rti.org)
#
# **Project #:** 0219481
#
# **Last modified:**
#
# **Status:** in progress
#
# **QA Status:** reviewed by
#
# **Inputs:**
#
# **Outputs:**
#
# **Assumptions:**
#
# **Future work:**
#
# **Notes:** The average magnitude of the supply shortfall in the municipal sector.
