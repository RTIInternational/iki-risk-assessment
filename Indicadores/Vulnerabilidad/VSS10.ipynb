# %% [markdown]
# ### This notebook computes the "VSS10. Supply reliability for the municipal sector" indicator for the 27 basins of IKI Project
#
# **Spanish:** Confiabilidad de suministro para el sector poblacional
#
# **Created:** 1/22/2026 by Sophia Bakar (sbakar@rti.org)
#
# **Project #:** 0219481
#
# **Last modified:**
#
# **Status:** in progress
#
# **QA Status:** reviewed by
#
# **Inputs:**
#
# **Outputs:**
#
# **Assumptions:**
#
# **Future work:**
#
# **Notes:** The proportion of time during which water demand is fully met for the municipal sector.
